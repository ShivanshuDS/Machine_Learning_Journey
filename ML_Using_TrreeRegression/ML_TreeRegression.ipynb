# %% [markdown]
# ### ML_TreeRegression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('clean_laptopPrice.csv')
df
# Out:
#      Unnamed: 0  brand  processor_brand  processor_name  processor_gnrtn  \
# 0             0     10                1               3               10
# 1             1     20                1               3               10
# 2             2     20                1               3               10
# 3             3     10                1               5               10
# 4             4     10                1               1                0
# ..          ...    ...              ...             ...              ...
# 781         818     10                2              10                0
# 782         819     10                2              10                0
# 783         820     10                2              10                0
# 784         821     10                2              10                0
# 785         822     20                2               6               10
#
#      ram_gb  ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  \
# 0         4         1     0  1024   1      64                0       1
# 1         4         1     0  1024   1      64                0       1
# 2         4         1     0  1024   1      64                0       1
# 3         8         1   512     0   1      32                2       1
# 4         4         1     0   512   1      64                0       1
# ..      ...       ...   ...   ...  ..     ...              ...     ...
# 781       4         1  1024     0   1      64                0       1
# 782       4         1  1024     0   1      64                0       1
# 783       4         1  1024     0   1      64                4       1
# 784       4         1  1024     0   1      64                4       1
# 785       8         1   512     0   2      64                0       2
#
#      warranty  Touchscreen  msoffice   Price
# 0           0            0         0   34649
# 1           0            0         0   38999
# 2           0            0         0   39999
# 3           0            0         0   69990
# 4           0            0         0   26990
# ..        ...          ...       ...     ...
# 781         1            0         0  135990
# 782         1            0         0  144990
# 783         1            0         0  149990
# 784         1            0         0  142990
# 785         0            0         0   57490
#
# [786 rows x 17 columns]

# %%
x=df.drop('Price',axis=1)
x
# Out:
#      Unnamed: 0  brand  processor_brand  processor_name  processor_gnrtn  \
# 0             0     10                1               3               10
# 1             1     20                1               3               10
# 2             2     20                1               3               10
# 3             3     10                1               5               10
# 4             4     10                1               1                0
# ..          ...    ...              ...             ...              ...
# 781         818     10                2              10                0
# 782         819     10                2              10                0
# 783         820     10                2              10                0
# 784         821     10                2              10                0
# 785         822     20                2               6               10
#
#      ram_gb  ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  \
# 0         4         1     0  1024   1      64                0       1
# 1         4         1     0  1024   1      64                0       1
# 2         4         1     0  1024   1      64                0       1
# 3         8         1   512     0   1      32                2       1
# 4         4         1     0   512   1      64                0       1
# ..      ...       ...   ...   ...  ..     ...              ...     ...
# 781       4         1  1024     0   1      64                0       1
# 782       4         1  1024     0   1      64                0       1
# 783       4         1  1024     0   1      64                4       1
# 784       4         1  1024     0   1      64                4       1
# 785       8         1   512     0   2      64                0       2
#
#      warranty  Touchscreen  msoffice
# 0           0            0         0
# 1           0            0         0
# 2           0            0         0
# 3           0            0         0
# 4           0            0         0
# ..        ...          ...       ...
# 781         1            0         0
# 782         1            0         0
# 783         1            0         0
# 784         1            0         0
# 785         0            0         0
#
# [786 rows x 16 columns]

# %%
y=df[['Price']]
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 781  135990
# 782  144990
# 783  149990
# 784  142990
# 785   57490
#
# [786 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
dr=DecisionTreeRegressor(criterion='gini')# data kam ke liye gini use karege
dr.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
dr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dr.fit(x_train,y_train)
#
# File d:\Data Science Tranning\Data_Science\Lib\site-packages\sklearn\base.py:1329, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1324 partial_fit_and_fitted = (
#    1325     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1326 )
#    1328 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
#    1336     return fit_method(estimator, *args, **kwargs)
#
# File d:\Data Science Tranning\Data_Science\Lib\site-packages\sklearn\base.py:492, in BaseEstimator._validate_params(self)
#     484 def _validate_params(self):
#     485     """Validate types and values of constructor parameters
#     486
#     487     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    490     accepted constraints.
#     491     """
# --> 492     validate_parameter_constraints(
#     493         self._parameter_constraints,
#     494         self.get_params(deep=False),
#     495         caller_name=self.__class__.__name__,
#     496     )
#
# File d:\Data Science Tranning\Data_Science\Lib\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'absolute_error', 'friedman_mse', 'squared_error', 'poisson'}. Got 'gini' instead.

# %%
pred=dr.predict(x_test)

# %%
pred=dr.predict(x_test)
pred

# %%
pred[0:20]
